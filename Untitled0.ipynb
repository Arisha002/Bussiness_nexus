# %% [markdown]
# <a href="https://colab.research.google.com/github/Arisha002/Bussiness_nexus/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
name = "ali"
print("my name is ",name)
# Out:
# my name is  ali

# %%
name="arisha"
print("welcome to ai lab",name)
# Out:
# welcome to ai lab arisha

# %%
a=2+3
print(a)
# Out:
# 5

# %%
name=input("enter your name: ")
print("your name is ",name)
# Out:
# enter your name: arisha
# your name is  arisha

# %%
name=input("enter your name: ")
age=input("enter your age: ")
print("welcome to AI lab ",name)
print("age is ",age + "years old")
# Out:
# enter your name: arisha
# enter your age: 21
# welcome to AI lab  arisha
# age is  21years old

# %%
a=int(input("enter 1st num: "))
b=int(input("enter 2nd num: "))
print("sum is : ", a + b)
# Out:
# enter 1st num: 2
# enter 2nd num: 3
# sum is :  5

# %%
a=int(input("enter number: "))
print("cube of entered no is : ", a**3) #yeh cube karraha hai
# Out:
# enter number: 2
# square of entered no is :  8

# %%
num =int(input("enter your number: "))
for i in range (1,11):
  print(f"{num}*{i}=",num * i)
# Out:
# enter your number: 2
# 2*1= 2
# 2*2= 4
# 2*3= 6
# 2*4= 8
# 2*5= 10
# 2*6= 12
# 2*7= 14
# 2*8= 16
# 2*9= 18
# 2*10= 20

# %%
a=int(input("enter number: "))
if a % 2 == 0:
  print("even")
else:
  print("odd")
# Out:
# enter number: 3
# odd

# %%
num=int(input("enter number: "))
if num < 50:
  print("your grade is fail : ")
elif num > 70:
  print("your grade is : B")
elif num > 80:
  print("your grade is : A")
elif num > 90:
  print("your grade is : A+")
elif num < 0 and num > 100:
  print("not applicable")
else:
  print("not in list")

# %%
num = int(input("Enter number: "))

if num < 0 or num > 100:
    print("Not applicable")
elif num < 50:
    print("Your grade is: Fail")
elif num > 90:
    print("Your grade is: A+")
elif num > 80:
    print("Your grade is: A")
elif num > 70:
    print("Your grade is: B")
else:
    print("Not in list")

# %%
for i in range(5):
  print("ai")
# Out:
# ai
# ai
# ai
# ai
# ai
